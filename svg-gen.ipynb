# %%
from igraph import *

g = Graph([(0,1), (0,2), (2,3), (3,4), (4,2), (2,5), (5,0), (6,3), (5,6)])
g.vs['name'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George']
g.vs['age'] = [25, 31, 18, 47, 22, 23, 50]
g.vs['gender'] = ['f', 'm', 'f', 'm', 'f', 'm', 'm']
g.es['is_formal'] = [False, False, True, True, True, False, True, False, False]

g.es[0]['is_formal']  = True
g['date'] = '2009-01-10'

claire = g.vs.find(name='Claire')

layout = g.layout('kk')

g.vs["label"] = g.vs["name"]
color_dict = {"m": "green", "f": "blue"}
g.vs["color"] = [color_dict[gender] for gender in g.vs["gender"]]
plot(g, layout = layout, bbox = (300, 300), margin = 20)

# %%
from igraph import *

g = Graph([(0,1), (0,2), (2,3), (3,4), (4,2), (2,5), (5,0), (6,3), (5,6)])
g.vs['name'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George']
g.vs['age'] = [25, 31, 18, 47, 22, 23, 50]
g.vs['gender'] = ['f', 'm', 'f', 'm', 'f', 'm', 'm']
g.es['is_formal'] = [False, False, True, True, True, False, True, False, False]

g.es[0]['is_formal']  = True
g['date'] = '2009-01-10'

claire = g.vs.find(name='Claire')

layout = g.layout('kk')

g.vs["label"] = g.vs["name"]
color_dict = {"m": "green", "f": "blue"}
g.vs["color"] = [color_dict[gender] for gender in g.vs["gender"]]
plot(g, layout = layout, bbox = (300, 300), margin = 20)

# %%
g = Graph.Tree(16, 2)
layout = g.layout('rt', 1)
g.vs['label'] = ['one']
plot(g, layout=layout)

# %%
g = Graph.Tree(8, 4)
layout = g.layout('rt', 1)
g.vs['color'] = ['green']
g.vs['label'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George', 'Harry']
plot(g, layout=layout)

# %%
g2 = Graph.Tree(127, 2)

# %%
print g2
# Out:
# IGRAPH U--- 127 126 --
# + edges:
# 0--1 0--2 1--3 1--4 2--5 2--6 3--7 3--8 4--9 4--10 5--11 5--12 6--13 6--14
# 7--15 7--16 8--17 8--18 9--19 9--20 10--21 10--22 11--23 11--24 12--25 12--26
# 13--27 13--28 14--29 14--30 15--31 15--32 16--33 16--34 17--35 17--36 18--37
# 18--38 19--39 19--40 20--41 20--42 21--43 21--44 22--45 22--46 23--47 23--48
# 24--49 24--50 25--51 25--52 26--53 26--54 27--55 27--56 28--57 28--58 29--59
# 29--60 30--61 30--62 31--63 31--64 32--65 32--66 33--67 33--68 34--69 34--70
# 35--71 35--72 36--73 36--74 37--75 37--76 38--77 38--78 39--79 39--80 40--81
# 40--82 41--83 41--84 42--85 42--86 43--87 43--88 44--89 44--90 45--91 45--92
# 46--93 46--94 47--95 47--96 48--97 48--98 49--99 49--100 50--101 50--102
# 51--103 51--104 52--105 52--106 53--107 53--108 54--109 54--110 55--111
# 55--112 56--113 56--114 57--115 57--116 58--117 58--118 59--119 59--120
# 60--121 60--122 61--123 61--124 62--125 62--126

# %%
plot(g2, layout=layout)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python2.7/site-packages/igraph/drawing/__init__.pyc in _repr_svg_(self)
#     347         context = cairo.Context(surface)
#     348         # Plot the graph on this context
# --> 349         self.redraw(context)
#     350         # No idea why this is needed but python crashes without
#     351         context.show_page()
#
# /usr/local/lib/python2.7/site-packages/igraph/drawing/__init__.pyc in redraw(self, context)
#     267                 else:
#     268                     ctx.save()
# --> 269                 plotter(ctx, bbox, palette, *args, **kwds)
#     270                 if opacity < 1.0:
#     271                     ctx.pop_group_to_source()
#
# /usr/local/lib/python2.7/site-packages/igraph/__init__.pyc in __plot__(self, context, bbox, palette, *args, **kwds)
#    3150             del kwds["drawer_factory"]
#    3151         drawer = drawer_factory(context, bbox)
# -> 3152         drawer.draw(self, palette, *args, **kwds)
#    3153
#    3154     def __str__(self):
#
# /usr/local/lib/python2.7/site-packages/igraph/drawing/graph.pyc in draw(self, graph, palette, *args, **kwds)
#     257         # Construct the visual vertex/edge builders based on the specifications
#     258         # provided by the vertex_drawer and the edge_drawer
# --> 259         vertex_builder = vertex_drawer.VisualVertexBuilder(graph.vs, kwds)
#     260         edge_builder = edge_drawer.VisualEdgeBuilder(graph.es, kwds)
#     261
#
# /usr/local/lib/python2.7/site-packages/igraph/drawing/metamagic.pyc in __init__(self, seq, kwds)
#     220
#     221         for attr_spec in self._attributes:
# --> 222             values = self._collect_attributes(attr_spec)
#     223             attr_name = attr_spec.name
#     224             for cache_elt, val in izip(self._cache, values):
#
# /usr/local/lib/python2.7/site-packages/igraph/drawing/metamagic.pyc in _collect_attributes(self, attr_spec, config)
#     270         if attr_spec.func is not None:
#     271             func = attr_spec.func
# --> 272             result = [func(i) for i in xrange(n)]
#     273             return result
#     274
#
# /usr/local/lib/python2.7/site-packages/igraph/layout.pyc in __getitem__(self, idx)
#      98
#      99     def __getitem__(self, idx):
# --> 100         return self._coords[idx]
#     101
#     102     def __setitem__(self, idx, value):
#
# IndexError: list index out of range

# %%
g = Graph.Tree(7, 2)
layout =  layout('rt')
g.vs['color'] = ['green']
g.vs['label'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George', 'Harry']
plot(g, layout=layout)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-cca0e5061f1c> in <module>()
#       1 g = Graph.Tree(7, 2)
# ----> 2 layout =  layout('rt')
#       3 g.vs['color'] = ['green']
#       4 g.vs['label'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George', 'Harry']
#       5 plot(g, layout=layout)
#
# TypeError: 'Layout' object is not callable

# %%
import igraph as ig
g = ig.Graph(n = 12, directed=True)
g.add_edges([(1,0),(2,1), (3,2), (4,3),
             (5,1),
             (6,2), (7,6), (8,7),
             (9,0),
             (10,0), (11,10)])
g.vs["label"] = ["A", "B", "A", "B", "C", "F", "C", "B", "D", "C", "D", "F"]
ig.plot(g, layout="rt")

# %%
g = Graph.Tree(7, 2)
layout =  g.layout('rt')
g.vs['color'] = ['green']
g.vs['label'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George', 'Harry']
plot(g, layout=layout)

# %%
import igraph as ig
g = ig.Graph(n = 12, directed=True)
g.add_edges([(1,0),(2,1), (3,2), (4,3),
             (5,1),
             (6,2), (7,6), (8,7),
             (9,0),
             (10,0), (11,10)])
g.vs["label"] = ["A", "B", "A", "B", "C", "F", "C", "B", "D", "C", "D", "F"]
layout = g.layout_reingold_tilford(mode="in", root=[0])
ig.plot(g, layout=layout)

# %%
g = Graph.Tree(7, 2)
layout = g.layout_reingold_tilford(mode="in", root=[0])
g.vs['label'] = ['Alice', 'Bob', 'Claire', 'Dennis', 'Esther', 'Frank', 'George', 'Harry']
plot(g, layout=layout)
